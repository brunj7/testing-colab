# %%
import pandas as pd   # did not have to install pandas to
from google.colab import drive

# %% [markdown]
# ## Testing input/output to Google Drive
#
# Greg was here
# Greg makes another change

# %%
# Mounting my Google drive to the runtime env
# https://colab.research.google.com/notebooks/io.ipynb#scrollTo=RWSJpsyKqHjH
drive.mount('/content/drive') # name of the folder at the root of my google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Checking if I can see the files
#!ls "/content/drive/My Drive/Colab_data_testing"
# !ls "/content/drive/Shareddrives/Research Data Services/Colab_data_testing"
# Out:
# 'Blue whales Eastern North Pacific 1993-2008 - Argos data.csv'

# %%
# read a random csv file
whale_data = pd.read_csv("/content/drive/Shareddrives/Research Data Services/Colab_data_testing/Blue whales Eastern North Pacific 1993-2008 - Argos data.csv")

# %%
whale_data.head()
# Out:
#       event-id  visible                timestamp  location-long  location-lat  \
# 0  18347727173     True  1993-08-29 01:23:17.000       -122.407        36.981
# 1  18347727174     True  1993-08-31 13:04:34.000       -122.788        37.637
# 2  18347727175     True  1993-09-01 01:57:39.000       -122.827        37.166
# 3  18347727180     True  1993-09-01 22:35:12.000       -123.466        38.184
# 4  18347727182     True  1993-09-01 03:40:17.000       -123.410        37.141
#
#    argos:best-level  argos:calcul-freq  argos:iq  argos:lat1  argos:lat2  ...  \
# 0            -126.0       4.016497e+08       NaN      36.981      47.285  ...
# 1            -126.0       6.496602e+05       NaN      37.637      39.596  ...
# 2            -129.0       6.496602e+05       NaN      37.166      44.267  ...
# 3            -127.0       6.494532e+05       NaN      38.184      45.262  ...
# 4            -131.0       6.496431e+05       NaN      37.141      34.968  ...
#
# ...

# %%
# unmount the drive
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
# Out:
# All changes made in this colab session should now be visible in Drive.
